# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 150px; float: left;"> <img src="data/D4Sci_logo_ball.png" alt="Data For Science, Inc" align="left" border="0"> </div>
#     <div style="float: left; margin-left: 10px;">
#         <h1>Time Series Analysis</h1>
#         <h1>Data Exploration</h1>
#         <p>Bruno Gonçalves<br/>
#         <a href="http://www.data4sci.com/">www.data4sci.com</a><br/>
#         @bgoncalves, @data4sci</p></div>
# </div>

# %%
# !pip install watermark
# Out:
# Requirement already satisfied: watermark in /opt/conda/lib/python3.11/site-packages (2.4.2)
# Requirement already satisfied: ipython>=6.0 in /opt/conda/lib/python3.11/site-packages (from watermark) (8.14.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /opt/conda/lib/python3.11/site-packages (from watermark) (6.6.0)
# Requirement already satisfied: py3nvml>=0.2 in /opt/conda/lib/python3.11/site-packages (from watermark) (0.2.7)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from watermark) (67.7.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=1.4->watermark) (3.15.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (2.15.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.0->watermark) (4.8.0)
# Requirement already satisfied: xmltodict in /opt/conda/lib/python3.11/site-packages (from py3nvml>=0.2->watermark) (0.13.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.0->watermark) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.0->watermark) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.0->watermark) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.0->watermark) (0.2.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.0->watermark) (1.16.0)

# %%
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

import watermark

# %matplotlib inline
# %load_ext watermark

# %% [markdown]
# List out the versions of all loaded libraries

# %%
# %watermark -n -v -m -g -iv
# Out:
# Python implementation: CPython
# Python version       : 3.11.3
# IPython version      : 8.14.0
#
# Compiler    : GCC 11.3.0
# OS          : Linux
# Release     : 5.15.49-linuxkit
# Machine     : aarch64
# Processor   : aarch64
# CPU cores   : 4
# Architecture: 64bit
#
# Git hash:
#
# pandas    : 2.0.2
# numpy     : 1.24.3
# watermark : 2.4.2
# matplotlib: 3.7.1
# fatal: not a git repository (or any parent up to mount point /home/jovyan)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %% [markdown]
# Set the default figure style

# %%
plt.style.use('./d4sci.mplstyle')

# %% [markdown]
# ## GDP

# %% [markdown]
# The first timeseries will consider is the US Quarterly GDP for the past 70 years.

# %%
GDP = pd.read_csv('data/GDP.csv', parse_dates=['DATE'])

# %%
GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    290 non-null    datetime64[ns]
#  1   GDP     290 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.7 KB

# %%
GDP.set_index('DATE', inplace=True)

# %%
GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 290 entries, 1947-01-01 to 2019-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDP     290 non-null    float64
# dtypes: float64(1)
# memory usage: 4.5 KB

# %%
GDP.head()
# Out:
#                  GDP
# DATE
# 1947-01-01  2033.061
# 1947-04-01  2027.639
# 1947-07-01  2023.452
# 1947-10-01  2055.103
# 1948-01-01  2086.017

# %%
ax = GDP.plot(legend=False)
ax.set_ylabel(r'GDP ($\$B$)')
# Out:
# Text(0, 0.5, 'GDP ($\\$B$)')

# %% [markdown]
# It displays a clear upward trend

# %% [markdown]
# ## Influenza mortality

# %% [markdown]
# Next, we look the percentage of deaths attributed to Influenza and Pneumonia in the past 8 years

# %%
ILI = pd.read_csv('data/CDC.csv')

# %%
ILI.head()
# Out:
#    Year  Week  Percent of Deaths Due to Pneumonia and Influenza  Expected  \
# 0  2012     1                                          8.479120   8.15718
# 1  2012     2                                          8.343472   8.22181
# 2  2012     3                                          8.370908   8.27534
# 3  2012     4                                          8.448458   8.31696
# 4  2012     5                                          8.140332   8.34602
#
#    Threshold  All Deaths  Pneumonia Deaths  Influenza Deaths
# 0    8.49104       51102              4323                10
# 1    8.55556       50962              4245                 7
# 2    8.60898       51010              4261                 9
# 3    8.65049       50163              4227                11
# 4    8.67945       49568              4026                 9

# %%
ILI['date'] = ILI['Year']+ILI['Week']/52.

# %%
ILI.head()
# Out:
#    Year  Week  Percent of Deaths Due to Pneumonia and Influenza  Expected  \
# 0  2012     1                                          8.479120   8.15718
# 1  2012     2                                          8.343472   8.22181
# 2  2012     3                                          8.370908   8.27534
# 3  2012     4                                          8.448458   8.31696
# 4  2012     5                                          8.140332   8.34602
#
#    Threshold  All Deaths  Pneumonia Deaths  Influenza Deaths         date
# 0    8.49104       51102              4323                10  2012.019231
# 1    8.55556       50962              4245                 7  2012.038462
# 2    8.60898       51010              4261                 9  2012.057692
# 3    8.65049       50163              4227                11  2012.076923
# 4    8.67945       49568              4026                 9  2012.096154

# %%
ILI.plot(x='date', 
         y=['Percent of Deaths Due to Pneumonia and Influenza', 
            'Expected', 
            'Threshold'])
ax = plt.gca()
ax.legend(['Mortality', 'Expected', 'Threshold'])
ax.set_xlabel('Date')
ax.set_ylabel('% Mortality')
# Out:
# Text(0, 0.5, '% Mortality')

# %% [markdown]
# The seasonal behavior in unmistakable. The purple curve illustrates the expected seasonal behavior, while the green curve displays the threshold above which we are facing an epidemic

# %% [markdown]
# ## Sun activity

# %% [markdown]
# The number of observed sun spots over 300 years also display a nice seasonal behavior over the course of a decade or so

# %%
Sun = pd.read_csv('data/sun.csv')

# %%
Sun.tail()
# Out:
#        YEAR  SUNACTIVITY
# 304  2004.0         40.4
# 305  2005.0         29.8
# 306  2006.0         15.2
# 307  2007.0          7.5
# 308  2008.0          2.9

# %%
ax = Sun.plot(x='YEAR', y='SUNACTIVITY', legend=False)
ax.set_ylabel('Sun spot activity')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ## Dow-Jones Industrial Average

# %% [markdown]
# The Dow-Jones Industrial Average also has a clear uptrend like GDP but with significantly larger flucutations

# %%
DJIA = pd.read_csv('data/DJIA.csv', parse_dates=['DATE'], na_values='.')

# %%
DJIA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2609 entries, 0 to 2608
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    2609 non-null   datetime64[ns]
#  1   DJIA    2515 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 40.9 KB

# %%
DJIA.set_index('DATE', inplace=True)

# %%
ax = DJIA['2017':'2018'].plot(legend=False)
ax.set_ylabel('DJIA')
ax.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Airline Passengers

# %% [markdown]
# The number of passenters in international flights in the 50s displays both a trend and a seasonal pattern

# %%
airline = pd.read_csv('data/international-airline-passengers.csv', sep=';')

# %%
airline.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
airline['Month'] = pd.to_datetime(airline['Month']+'-01')

# %%
airline.set_index('Month', inplace=True)

# %%
airline.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
ax = airline.plot(legend=False)
ax.set_xlabel('Date')
ax.set_ylabel('Passengers')
# Out:
# Text(0, 0.5, 'Passengers')

# %% [markdown]
# ## Types of non-stationarity

# %% [markdown]
# There are several kinds of non-stationarity. Here we illustrate the most common ones with simple toy examples

# %%
x = np.linspace(0, np.pi*10, 360)
y = np.sin(x)

# %% [markdown]
# We can generate the differnet kinds with a few simple algebraic manipulations

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 18))
axs[0][0].plot(x, y)
axs[0][0].set_title('Stationary series')
axs[0][0].set_xlabel('time')
axs[0][0].set_ylabel('Amplitude')

axs[0][1].plot(x, y+x/10)
axs[0][1].set_title('Changing mean')
axs[0][1].set_xlabel('time')
axs[0][1].set_ylabel('Amplitude')


axs[1][0].plot(x, y*x/10)
axs[1][0].set_title('Changing Variance')
axs[1][0].set_xlabel('time')
axs[1][0].set_ylabel('Amplitude')

axs[1][1].plot(np.sin(x+x*x/30))
axs[1][1].set_title('Changing Co-variance')
axs[1][1].set_xlabel('time')
axs[1][1].set_ylabel('Amplitude')

plt.tight_layout()

# %% [markdown]
# ## Kinds of trend

# %% [markdown]
# Two of the most common non-stationarity types are due to differnet kinds of trends that we illustrate here

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 9))
axs[0].plot(x, y+x/10)
axs[0].set_title('Additive Trend')
axs[0].set_xlabel('time')
axs[0].set_ylabel('Amplitude')


axs[1].plot(x, y*x/10)
axs[1].set_title('Multiplicative Trend')
axs[1].set_xlabel('time')
axs[1].set_ylabel('Amplitude')

plt.tight_layout()

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#      <img src="data/D4Sci_logo_full.png" alt="Data For Science, Inc" align="center" border="0" width=300px>
# </div>
